# %%
# 데이터 분석
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import clear_output

# %% [markdown]
# # detail data 전처리

# %%
# 데이터 불러오기
df = pd.read_csv('./data/detail.csv')
df
# Out:
#        Unnamed: 0                      DBid Damage dealt/Game Healed/Game  \
# 0               0  111029242162120119198225             9,374       3,840
# 1               1     118097079110147012121             7,959       3,180
# 2               2   49227144191214254099131             7,292       1,196
# 3               3   38106188000007136056188             6,118       9,361
# 4               4   13080044060015097186088             9,188       1,910
# ...           ...                       ...               ...         ...
# 22423       22423   27078075244099180087016             8,613       1,324
# 22424       22424  243116241127093034212249             6,337         800
# 22425       22425  238047226154239156241160             4,890       3,069
# 22426       22426  130145216197178069097108             4,019       2,805
# 22427       22427  238088121051143004100151             4,962       1,873
#
#                                           Time Played Time Played/Day  \
# 0      17 hours\n                                            17 hours
# 1      85 hours\n                                            85 hours
# 2      29 hours\n                                            29 hours
# 3      11 hours\n                                            11 hours
# 4      55 hours\n                                            55 hours
# ...                                               ...             ...
# 22423  53 hours\n                                            53 hours
# 22424   8 hours\n                                             8 hours
# 22425   6 hours\n                                             6 hours
# 22426   4 hours\n                                             4 hours
# 22427   6 hours\n                                             6 hours
#
#       Time on fire Avg Time on Fire Avg Obj Time Avg Obj Kills  Cards  \
# 0      2시간 22분 38초            01:34      36 secs          5.71     43
# 1      8시간 55분 31초            01:15        1 min          6.34    146
# 2      2시간 41분 34초            00:58        1 min          7.14     71
# 3      1시간 19분 11초            01:25      59 secs          6.04     28
# 4      6시간 52분 17초            01:25      42 secs          6.71    122
# ...            ...              ...          ...           ...    ...
# 22423  4시간 22분 10초            00:54        1 min          8.38     96
# 22424      28분 44초            00:35        1 min          6.00     10
# 22425      22분 59초            00:34        1 min          6.95      8
# 22426       3분 10초            00:08        1 min          7.84      5
# 22427      23분 21초            00:36        1 min          6.21      5
#
#        Avg Medals/Game Gold  Silver  Bronze
# 0                    3  129      93      58
# 1                    3  437     427     359
# 2                    3  181     156     145
# 3                    3   51      52      40
# 4                    3  312     222     204
# ...                ...  ...     ...     ...
# 22423                3  303     272     218
# 22424                2   25      31      37
# 22425                2   15      36      30
# 22426                2    7      18      18
# 22427                2   19      30      32
#
# [22428 rows x 15 columns]

# %%
# 불필요한 변수 삭제
del df['Unnamed: 0']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22428 entries, 0 to 22427
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DBid               22428 non-null  object
#  1   Damage dealt/Game  22428 non-null  object
#  2   Healed/Game        22428 non-null  object
#  3   Time Played        22428 non-null  object
#  4   Time Played/Day    22428 non-null  object
#  5   Time on fire       22428 non-null  object
#  6   Avg Time on Fire   22412 non-null  object
#  7   Avg Obj Time       22428 non-null  object
#  8   Avg Obj Kills      22428 non-null  object
#  9   Cards              22428 non-null  int64
#  10  Avg Medals/Game    22428 non-null  int64
#  11  Gold               22428 non-null  object
#  12  Silver             22428 non-null  int64
#  13  Bronze             22428 non-null  int64
# dtypes: int64(4), object(10)
# memory usage: 2.4+ MB

# %%
df.head()
# Out:
#                        DBid Damage dealt/Game Healed/Game  \
# 0  111029242162120119198225             9,374       3,840
# 1     118097079110147012121             7,959       3,180
# 2   49227144191214254099131             7,292       1,196
# 3   38106188000007136056188             6,118       9,361
# 4   13080044060015097186088             9,188       1,910
#
#                                       Time Played Time Played/Day  \
# 0  17 hours\n                                            17 hours
# 1  85 hours\n                                            85 hours
# 2  29 hours\n                                            29 hours
# 3  11 hours\n                                            11 hours
# 4  55 hours\n                                            55 hours
#
#   Time on fire Avg Time on Fire Avg Obj Time Avg Obj Kills  Cards  \
# 0  2시간 22분 38초            01:34      36 secs          5.71     43
# 1  8시간 55분 31초            01:15        1 min          6.34    146
# 2  2시간 41분 34초            00:58        1 min          7.14     71
# 3  1시간 19분 11초            01:25      59 secs          6.04     28
# 4  6시간 52분 17초            01:25      42 secs          6.71    122
#
#    Avg Medals/Game Gold  Silver  Bronze
# 0                3  129      93      58
# 1                3  437     427     359
# 2                3  181     156     145
# 3                3   51      52      40
# 4                3  312     222     204

# %%
df.loc[1:4, 'DBid']
df.iloc[1:4, 3:4]
# Out:
#                                       Time Played
# 1  85 hours\n
# 2  29 hours\n
# 3  11 hours\n

# %%
# Damaage dealt/Game & Healed/Game 변수
